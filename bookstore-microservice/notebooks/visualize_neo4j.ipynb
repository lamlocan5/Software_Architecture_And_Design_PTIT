# %% [markdown]
# # Neo4j Graph Database Recommendation System Visualization
#
# This notebook demonstrates how to connect to the Neo4j Graph Database, query users, products, and relationships, visualize the graph structure, and get graph-based recommendations.

# %%
import os
import sys
import django

# Setup Django environment
sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../ai-service'))
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'recommender_ai_service.settings')

# Configure database connection details for local development outside Docker
os.environ['DB_HOST'] = '127.0.0.1'
os.environ['DB_NAME'] = 'bookstore_ai'
os.environ['NEO4J_URI'] = 'bolt://localhost:7687'
os.environ['NEO4J_USERNAME'] = 'neo4j'
os.environ['NEO4J_PASSWORD'] = 'password123'

# Allow synchronous operations in Jupyter's async context
os.environ['DJANGO_ALLOW_ASYNC_UNSAFE'] = 'true'

django.setup()
print("Django & Neo4j environment setup successfully!")
# Out:
# Django & Neo4j environment setup successfully!

# %%
from app.graph_engine import Neo4jGraphEngine

# Initialize Neo4j graph engine
engine = Neo4jGraphEngine()
if engine.driver:
    with engine.driver.session() as session:
        # Query node counts
        users = session.run("MATCH (u:User) RETURN count(u) AS count").single()["count"]
        products = session.run("MATCH (p:Product) RETURN count(p) AS count").single()["count"]
        
        # Query relationship counts
        buys = session.run("MATCH ()-[r:BUY]->() RETURN count(r) AS count").single()["count"]
        views = session.run("MATCH ()-[r:VIEW]->() RETURN count(r) AS count").single()["count"]
        similars = session.run("MATCH ()-[r:SIMILAR]->() RETURN count(r) AS count").single()["count"]
        
        print("=== Neo4j Graph Database Statistics ===")
        print(f"Users (User):            {users}")
        print(f"Products (Product):      {products}")
        print(f"BUY Relationships:       {buys}")
        print(f"VIEW Relationships:      {views}")
        print(f"SIMILAR Relationships:   {similars}")
else:
    print("Failed to connect to Neo4j database. Check that the service is running.")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:512, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, deadline, keep_alive, ssl_context)
#     511 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 512 s.connect(resolved_address)
#     513 s.settimeout(t)
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_bolt_socket.py:329, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     328 try:
# --> 329     s = cls._connect_secure(
#     330         resolved_address,
#     331         tcp_timeout,
#     332         deadline,
#     333         keep_alive,
#     334         ssl_context,
#     335     )
#     336     agreed_version = s._handshake(resolved_address, deadline)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:523, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, deadline, keep_alive, ssl_context)
#     522 if isinstance(error, OSError):
# --> 523     raise ServiceUnavailable(
#     524         "Failed to establish connection to "
#     525         f"{resolved_address!r} (reason {error})"
#     526     ) from error
#     527 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] No connection could be made because the target machine actively refused it)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[7], line 8
#       5 if engine.driver:
#       6     with engine.driver.session() as session:
#       7         # Query node counts
# ----> 8         users = session.run("MATCH (u:User) RETURN count(u) AS count").single()["count"]
#       9         products = session.run("MATCH (p:Product) RETURN count(p) AS count").single()["count"]
#      11         # Query relationship counts
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\work\session.py:305, in Session.run(self, query, parameters, **kwargs)
#     302     self._auto_result._buffer_all()
#     304 if not self._connection:
# --> 305     self._connect(self._config.default_access_mode)
#     306     assert self._connection is not None
#     307 cx = self._connection
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\work\session.py:126, in Session._connect(self, access_mode, **acquire_kwargs)
#     124     access_mode = self._config.default_access_mode
#     125 try:
# --> 126     super()._connect(
#     127         access_mode, auth=self._config.auth, **acquire_kwargs
#     128     )
#     129 except asyncio.CancelledError:
#     130     self._handle_cancellation(message="_connect")
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\work\workspace.py:181, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)    178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#     180 acquire_kwargs_.update(acquire_kwargs)
# --> 181 self._connection = self._pool.acquire(**acquire_kwargs_)
#     182 if (
#     183     target_db.guessed
#     184     and not self._pinned_database
#    (...)    188     # support SSR.
#     189     # => we need to fall back to explicit home database resolution
#     190     log.debug(
#     191         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     192         "falling back to explicit home database resolution",
#     193     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_pool.py:678, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     671 deadline = acquisition_timeout_to_deadline(timeout)
#     672 log.debug(
#     673     "[#0000]  _: <POOL> acquire direct connection, "
#     674     "access_mode=%r, database=%r",
#     675     access_mode,
#     676     database,
#     677 )
# --> 678 return self._acquire(
#     679     self.address, auth, deadline, liveness_check_timeout, unprepared
#     680 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_pool.py:418, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     413             raise ConnectionAcquisitionTimeoutError(
#     414                 "failed to obtain a connection from the pool within "
#     415                 f"{deadline.original_timeout!r}s (timeout)"
#     416             )
#     417 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418 return connection_creator()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_pool.py:231, in IOPool._acquire_new_later.<locals>.connection_creator()
#     229 try:
#     230     try:
# --> 231         connection = self.opener(
#     232             address, auth or self.pool_config.auth, deadline
#     233         )
#     234     except ServiceUnavailable:
#     235         self.deactivate(address)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_pool.py:638, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     637 def opener(addr, auth_manager, deadline):
# --> 638     return Bolt.open(
#     639         addr,
#     640         auth_manager=auth_manager,
#     641         deadline=deadline,
#     642         routing_context=None,
#     643         pool_config=pool_config,
#     644     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_bolt.py:368, in Bolt.open(address, auth_manager, deadline, routing_context, pool_config)
#     365 if deadline is None:
#     366     deadline = Deadline(None)
# --> 368 s, protocol_version = BoltSocket.connect(
#     369     address,
#     370     tcp_timeout=pool_config.connection_timeout,
#     371     deadline=deadline,
#     372     custom_resolver=pool_config.resolver,
#     373     ssl_context=pool_config.get_ssl_context(),
#     374     keep_alive=pool_config.keep_alive,
#     375 )
#     377 pool_config.protocol_version = protocol_version
#     378 protocol_handlers = Bolt.protocol_handlers
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\io\_bolt_socket.py:380, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     378 else:
#     379     error_strs = "\n".join(map(str, errors))
# --> 380     raise ServiceUnavailable(
#     381         f"Couldn't connect to {address} (resolved to {address_strs}):"
#     382         f"\n{error_strs}"
#     383     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] No connection could be made because the target machine actively refused it)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [WinError 10061] No connection could be made because the target machine actively refused it)

# %%
import networkx as nx
import matplotlib.pyplot as plt

if engine.driver:
    G = nx.MultiDiGraph()
    
    with engine.driver.session() as session:
        # Retrieve all nodes and relationships
        result = session.run("MATCH (n)-[r]->(m) RETURN labels(n)[0] as l1, n.id as id1, type(r) as rel, labels(m)[0] as l2, m.id as id2")
        
        for row in result:
            node1 = f"{row['l1']}_{row['id1']}"
            node2 = f"{row['l2']}_{row['id2']}"
            G.add_node(node1, label=row['l1'], id=row['id1'])
            G.add_node(node2, label=row['l2'], id=row['id2'])
            G.add_edge(node1, node2, type=row['rel'])
            
    # Configure plot properties
    plt.figure(figsize=(12, 10))
    pos = nx.spring_layout(G, seed=42, k=0.5)
    
    # Draw nodes by label
    user_nodes = [node for node, attr in G.nodes(data=True) if attr.get('label') == 'User']
    product_nodes = [node for node, attr in G.nodes(data=True) if attr.get('label') == 'Product']
    
    nx.draw_networkx_nodes(G, pos, nodelist=user_nodes, node_color='lightblue', node_size=700, label='Users')
    nx.draw_networkx_nodes(G, pos, nodelist=product_nodes, node_color='lightgreen', node_size=700, label='Products')
    
    # Draw edges by type
    buy_edges = [(u, v) for u, v, k, attr in G.edges(data=True, keys=True) if attr.get('type') == 'BUY']
    view_edges = [(u, v) for u, v, k, attr in G.edges(data=True, keys=True) if attr.get('type') == 'VIEW']
    similar_edges = [(u, v) for u, v, k, attr in G.edges(data=True, keys=True) if attr.get('type') == 'SIMILAR']
    
    nx.draw_networkx_edges(G, pos, edgelist=buy_edges, edge_color='red', width=2, label='BUY', arrows=True)
    nx.draw_networkx_edges(G, pos, edgelist=view_edges, edge_color='orange', width=1, label='VIEW', arrows=True)
    # Draw SIMILAR as dashed thin grey lines to avoid cluttering
    nx.draw_networkx_edges(G, pos, edgelist=similar_edges, edge_color='grey', width=0.5, style='dashed', arrows=False)
    
    # Draw labels
    labels = {node: f"{attr.get('label')} {attr.get('id')}" for node, attr in G.nodes(data=True)}
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=8, font_family='sans-serif')
    
    plt.title("Neo4j Recommendation System Graph Structure")
    plt.legend(scatterpoints=1)
    plt.axis('off')
    plt.show()
else:
    print("Neo4j driver is not available.")

# %%
from pyvis.network import Network
import IPython
import builtins

if engine.driver:
    # Create pyvis network
    net = Network(notebook=True, height='600px', width='100%', bgcolor='#222222', font_color='white', cdn_resources='in_line')
    
    # Configure physics for nice interactive spreading
    net.barnes_hut()
    
    with engine.driver.session() as session:
        # Fetch all User nodes
        users_res = session.run("MATCH (u:User) RETURN u.id as id")
        for row in users_res:
            net.add_node(f"User_{row['id']}", label=f"User {row['id']}", color='#2c3e50', size=25)
            
        # Fetch all Product nodes
        products_res = session.run("MATCH (p:Product) RETURN p.id as id")
        for row in products_res:
            net.add_node(f"Product_{row['id']}", label=f"Product {row['id']}", color='#27ae60', size=20)
            
        # Fetch all relationships
        rels_res = session.run("MATCH (n)-[r]->(m) RETURN labels(n)[0] as l1, n.id as id1, type(r) as rel, labels(m)[0] as l2, m.id as id2")
        for row in rels_res:
            source = f"{row['l1']}_{row['id1']}"
            target = f"{row['l2']}_{row['id2']}"
            rel_type = row['rel']
            
            if rel_type == 'BUY':
                net.add_edge(source, target, title='BUY', color='#e74c3c', width=3)
            elif rel_type == 'VIEW':
                net.add_edge(source, target, title='VIEW', color='#f39c12', width=1.5)
            elif rel_type == 'SIMILAR':
                net.add_edge(source, target, title='SIMILAR', color='#95a5a6', width=0.5, dashes=True)
                
    # Save visual html
    html_path = 'neo4j_graph.html'
    
    # Temporarily monkeypatch builtins.open to force utf-8 encoding for Pyvis template writing on Windows
    orig_open = builtins.open
    try:
        def utf8_open(*args, **kwargs):
            if len(args) > 1 and ('w' in args[1] or 'a' in args[1]):
                kwargs['encoding'] = 'utf-8'
            elif 'mode' in kwargs and ('w' in kwargs['mode'] or 'a' in kwargs['mode']):
                kwargs['encoding'] = 'utf-8'
            return orig_open(*args, **kwargs)
        builtins.open = utf8_open
        
        net.show(html_path)
        print(f"Interactive graph saved to {html_path}")
    finally:
        builtins.open = orig_open
else:
    print("Neo4j driver is not available.")
# Out:
# neo4j_graph.html
# Interactive graph saved to neo4j_graph.html

# %%
# Test fetching recommendations
user_id = 7
print(f"=== Collaborative Filtering Recommendations for User {user_id} ===")
collab_recs = engine.get_collaborative_recommendations(user_id=user_id, limit=5)
for idx, (pid, score) in enumerate(collab_recs):
    print(f"{idx+1}. Product ID: {pid} (Collaborative Score: {score:.2f})")

print(f"\n=== Similarity Recommendations for User {user_id} ===")
sim_recs = engine.get_similar_recommendations(user_id=user_id, limit=5)
for idx, (pid, score) in enumerate(sim_recs):
    print(f"{idx+1}. Product ID: {pid} (Similarity Score: {score:.4f})")

engine.close()
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: BUY)", position=<SummaryInputPosition line=2, column=30, offset=38>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 30, 'offset': 38, 'line': 2}}> for query: '\n        MATCH (u1:User {id: $uid})-[:BUY]->(p:Product)<-[:BUY]-(u2:User)-[:BUY]->(rec:Product)\n        WHERE NOT (u1)-[:BUY|VIEW]->(rec) AND rec.id <> p.id\n        RETURN rec.id AS product_id, count(u2) AS score\n        ORDER BY score DESC\n        LIMIT $limit\n        '
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: BUY)", position=<SummaryInputPosition line=2, column=68, offset=76>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 68, 'offset': 76, 'line': 2}}> for query: '\n        MATCH (u1:User {id: $uid})-[:BUY]->(p:Product)<-[:BUY]-(u2:User)-[:BUY]->(rec:Product)\n        WHERE NOT (u1)-[:BUY|VIEW]->(rec) AND rec.id <> p.id\n        RETURN rec.id AS product_id, count(u2) AS score\n        ORDER BY score DESC\n        LIMIT $limit\n        '
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: BUY)", position=<SummaryInputPosition line=2, column=51, offset=59>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 51, 'offset': 59, 'line': 2}}> for query: '\n        MATCH (u1:User {id: $uid})-[:BUY]->(p:Product)<-[:BUY]-(u2:User)-[:BUY]->(rec:Product)\n        WHERE NOT (u1)-[:BUY|VIEW]->(rec) AND rec.id <> p.id\n        RETURN rec.id AS product_id, count(u2) AS score\n        ORDER BY score DESC\n        LIMIT $limit\n        '
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: BUY)", position=<SummaryInputPosition line=3, column=34, offset=121>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 34, 'offset': 121, 'line': 3}}> for query: '\n        MATCH (u1:User {id: $uid})-[:BUY]->(p:Product)<-[:BUY]-(u2:User)-[:BUY]->(rec:Product)\n        WHERE NOT (u1)-[:BUY|VIEW]->(rec) AND rec.id <> p.id\n        RETURN rec.id AS product_id, count(u2) AS score\n        ORDER BY score DESC\n        LIMIT $limit\n        '
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: BUY)", position=<SummaryInputPosition line=2, column=34, offset=42>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 34, 'offset': 42, 'line': 2}}> for query: '\n        MATCH (u:User {id: $uid})-[:VIEW|BUY]->(p:Product)-[r:SIMILAR]->(rec:Product)\n        WHERE NOT (u)-[:VIEW|BUY]->(rec)\n        RETURN rec.id AS product_id, sum(r.score) AS score\n        ORDER BY score DESC\n        LIMIT $limit\n        '
# Received notification from DBMS server: <GqlStatusObject gql_status='01N42', status_description="One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: BUY)", position=<SummaryInputPosition line=3, column=38, offset=116>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/', '_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'column': 38, 'offset': 116, 'line': 3}}> for query: '\n        MATCH (u:User {id: $uid})-[:VIEW|BUY]->(p:Product)-[r:SIMILAR]->(rec:Product)\n        WHERE NOT (u)-[:VIEW|BUY]->(rec)\n        RETURN rec.id AS product_id, sum(r.score) AS score\n        ORDER BY score DESC\n        LIMIT $limit\n        '
# === Collaborative Filtering Recommendations for User 7 ===
#
# === Similarity Recommendations for User 7 ===
# 1. Product ID: 11 (Similarity Score: 0.6000)
# 2. Product ID: 10 (Similarity Score: 0.6000)
# 3. Product ID: 9 (Similarity Score: 0.6000)
# 4. Product ID: 8 (Similarity Score: 0.6000)
# 5. Product ID: 12 (Similarity Score: 0.6000)
